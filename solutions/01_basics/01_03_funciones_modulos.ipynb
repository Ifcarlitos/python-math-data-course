# %% [markdown]
# # Solucionario
#
# Este cuaderno contiene las soluciones a los ejercicios planteados.
#
# ---

# %% [markdown]
# # 3. Funciones y Programación Modular
#
# Las funciones nos permiten encapsular lógica reutilizable, un principio clave (DRY - Don't Repeat Yourself) en ingeniería de software.
#
# ## 3.1 Definición de Funciones

# %%
def saludar(nombre, mensaje="Hola"):
    """
    Imprime un saludo personalizado.
    Args:
        nombre (str): Nombre de la persona.
        mensaje (str, opcional): Mensaje de saludo. Por defecto "Hola".
    """
    print(f"{mensaje}, {nombre}!")

saludar("Ana")
saludar("Luis", "Buenos días")

# %% [markdown]
# ## 3.2 Retorno de Valores
# Las funciones pueden devolver resultados para ser usados posteriormente.

# %%
def cuadrado_y_cubo(x):
    return x**2, x**3  # Retorna una tupla automáticamente

cuad, cub = cuadrado_y_cubo(3)
print(f"Cuadrado: {cuad}, Cubo: {cub}")

# %% [markdown]
# ## 3.3 Funciones Lambda
# Funciones anónimas pequeñas, útiles para pasar como argumentos a otras funciones (por ejemplo, en `map` o `filter`).

# %%
doble = lambda x: x * 2
print(doble(5))

# Uso en ordenamiento
puntos = [(1, 2), (3, 1), (5, 0)]
# Ordenar por la segunda coordenada
puntos.sort(key=lambda p: p[1])
print(f"Ordenados por y: {puntos}")

# %% [markdown]
# ## 3.4 Módulos
# Python organiza el código en módulos (`.py`). Podemos importar funciones de la librería estándar o de archivos propios.
#
# ```python
# import math
# print(math.pi)
# ```

# %% [markdown]
# ## 3.5 Ejercicio: Implementación de Estadística Básica
# Crea una función llamada `estadisticas_basicas` que reciba una lista de números y devuelva un diccionario con:
# - La media
# - El valor máximo
# - El valor mínimo
#
# Tip: Puedes usar funciones integradas como `sum()`, `max()`, `min()`.

# %%
def estadisticas_basicas(datos):
    # Tu código aquí
    pass

datos = [10, 20, 5, 40, 15]
# print(estadisticas_basicas(datos))
